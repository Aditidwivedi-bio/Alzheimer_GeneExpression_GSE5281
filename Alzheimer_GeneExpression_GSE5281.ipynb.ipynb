# %% [markdown]
# # Gene Expression Analysis of Alzheimer's Disease (GSE5281)
#
# This project analyzes the GSE5281 microarray dataset from the Gene Expression Omnibus (GEO)
# to identify differentially expressed genes between Alzheimer's disease and control brain samples.
#
# **Workflow includes:**
# - Data loading and cleaning
# - Exploratory data analysis (PCA)
# - Differential expression testing
# - Visualization (Volcano plot)

# %%
# !pip install GEOparse pandas numpy seaborn matplotlib scipy scikit-learn

import GEOparse
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.decomposition import PCA

# %% [markdown]
# ## Step 1: Install & Import Libraries
#
# Here we install and import required Python libraries. GEOparse will download the dataset from GEO. Pandas and NumPy handle data processing,
# Seaborn and Matplotlib are used for plotting, and SciPy is used for statistical testing.

# %%
# Download GSE5281 dataset
gse = GEOparse.get_GEO("GSE5281", destdir="./")

# Extract expression data
gpl = gse.gpls[list(gse.gpls.keys())[0]]  # platform
samples = gse.gsms
# Out:
# 29-Jul-2025 20:51:49 DEBUG utils - Directory ./ already exists. Skipping.
# DEBUG:GEOparse:Directory ./ already exists. Skipping.
# 29-Jul-2025 20:51:49 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE5nnn/GSE5281/soft/GSE5281_family.soft.gz to ./GSE5281_family.soft.gz
# INFO:GEOparse:Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE5nnn/GSE5281/soft/GSE5281_family.soft.gz to ./GSE5281_family.soft.gz
# 100%|██████████| 88.6M/88.6M [00:01<00:00, 84.2MB/s]
# 29-Jul-2025 20:51:50 DEBUG downloader - Size validation passed
# DEBUG:GEOparse:Size validation passed
# 29-Jul-2025 20:51:50 DEBUG downloader - Moving /tmp/tmp7_glnj0c to /content/GSE5281_family.soft.gz
# DEBUG:GEOparse:Moving /tmp/tmp7_glnj0c to /content/GSE5281_family.soft.gz
# 29-Jul-2025 20:51:50 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE5nnn/GSE5281/soft/GSE5281_family.soft.gz
# ...

# %% [markdown]
# ## Step 2: Download GSE5281 Dataset
#
# We download the dataset using GEOparse and create an expression matrix where rows are probes (genes) and columns are samples.
# We convert all values to numeric and remove missing values for a clean dataset.

# %%
import GEOparse

# Download GSE5281
gse = GEOparse.get_GEO("GSE5281", destdir="./")

# Load expression matrix directly from series matrix file
gse_data = gse.pivot_samples('VALUE')

# Check dimensions
print("Shape of data:", gse_data.shape)
gse_data.head()
# Out:
# 29-Jul-2025 20:52:59 DEBUG utils - Directory ./ already exists. Skipping.
# DEBUG:GEOparse:Directory ./ already exists. Skipping.
# 29-Jul-2025 20:52:59 INFO GEOparse - File already exist: using local version.
# INFO:GEOparse:File already exist: using local version.
# 29-Jul-2025 20:52:59 INFO GEOparse - Parsing ./GSE5281_family.soft.gz:
# INFO:GEOparse:Parsing ./GSE5281_family.soft.gz:
# 29-Jul-2025 20:52:59 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 29-Jul-2025 20:52:59 DEBUG GEOparse - SERIES: GSE5281
# DEBUG:GEOparse:SERIES: GSE5281
# 29-Jul-2025 20:52:59 DEBUG GEOparse - PLATFORM: GPL570
# DEBUG:GEOparse:PLATFORM: GPL570
# /usr/local/lib/python3.11/dist-packages/GEOparse/GEOparse.py:401: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(StringIO(data), index_col=None, sep="\t")
# 29-Jul-2025 20:53:01 DEBUG GEOparse - SAMPLE: GSM119615
# DEBUG:GEOparse:SAMPLE: GSM119615
# ...

# %% [markdown]
# ## Step 3: Data Loading & Expression Matrix Extraction
#
# In this step, we download the GSE5281 dataset from the Gene Expression Omnibus (GEO)
# using the GEOparse library. The function `pivot_samples('VALUE')` converts the raw GEO data
# into an **expression matrix**, where:
# - Rows = individual genes or probes
# - Columns = samples (Alzheimer’s or control)
#
# We check the shape of the dataset to see how many genes (rows) and samples (columns) are present.

# %%
# Use the pivoted matrix directly
expression_df = gse.pivot_samples('VALUE')

# Convert all values to numeric just in case
expression_df = expression_df.apply(pd.to_numeric, errors='coerce')

# Drop probes with missing values
expression_df = expression_df.dropna(axis=0, how='any')

print("Shape of cleaned data:", expression_df.shape)
expression_df.head()
# Out:
# Shape of cleaned data: (54675, 161)
# name        GSM119615   GSM119616    GSM119617    GSM119618   GSM119619  \
# ID_REF
# 1007_s_at  693.973300  807.145140  1722.625000  1668.057500  2231.29690
# 1053_at      9.755318   19.052270    13.060389    14.652245   138.67683
# 117_at      13.346846   18.217276    97.425470    98.197945   106.46844
# 121_at     173.092450  289.315400   537.182800   496.346560   477.86517
# 1255_g_at   52.616950  110.375984    99.021736    17.306772   628.81616
#
# name        GSM119620   GSM119621    GSM119622   GSM119623   GSM119624  ...  \
# ID_REF                                                                  ...
# 1007_s_at  990.541000  1396.82420  1026.056500  736.770300  938.817100  ...
# 1053_at      7.186742    10.17089    34.056934    7.829473   40.235332  ...
# 117_at      98.710520   164.32666    46.306164   35.067910   72.864900  ...
# 121_at     355.092000   467.56790   294.583280  224.524060  298.284730  ...
# ...

# %% [markdown]
# ## Step 4: Data Cleaning & Preprocessing
#
# In this step, we clean the expression matrix to make it ready for analysis:
# - `apply(pd.to_numeric)` converts all values to numeric form to avoid errors in calculations.
# - `dropna()` removes any genes (rows) with missing values to ensure accuracy in statistical testing.
#
# After cleaning, we check the dataset shape again to confirm how many genes and samples remain.

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(expression_df)

plt.figure(figsize=(6,4))
plt.scatter(pca_result[:,0], pca_result[:,1])
plt.title("PCA of Samples")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# ## Step 5: PCA for Exploratory Analysis
#
# Principal Component Analysis (PCA) is used to reduce high-dimensional gene expression data
# into 2 main components (PC1 and PC2).
#
# This helps visualize whether samples group together based on disease status.
# If Alzheimer’s and control samples form separate clusters, it suggests differences
# in their gene expression profiles.

# %%
# Match samples with metadata
alz_samples = meta_data[meta_data['group'] == "Alzheimers"].index
control_samples = meta_data[meta_data['group'] == "Control"].index

# Perform t-test for each gene
p_values = []
log_fc = []

for gene in expression_df.index:
    group1 = expression_df.loc[gene, control_samples]
    group2 = expression_df.loc[gene, alz_samples]

    # log fold change
    fc = np.log2(group2.mean() / group1.mean())
    log_fc.append(fc)

    # t-test
    t_stat, p_val = stats.ttest_ind(group2, group1, equal_var=False)
    p_values.append(p_val)

# Create results dataframe
results_df = pd.DataFrame({
    "Gene": expression_df.index,
    "logFC": log_fc,
    "p_value": p_values
}).sort_values("p_value")

results_df.head(20)
# Out:
#               Gene     logFC       p_value
# 36659  227404_s_at -1.449986  6.599968e-19
# 39646    230392_at  1.463896  4.776116e-18
# 47807    238558_at  1.416735  2.861973e-17
# 36339    227084_at  1.544356  3.686969e-17
# 47017  237768_x_at  1.308841  9.497586e-17
# 52078  242829_x_at  1.318671  1.596882e-16
# 12570    203122_at -1.113865  3.149916e-16
# 53447  244197_x_at  1.129402  6.816775e-16
# 39910  230656_s_at -1.646064  7.511715e-16
# 44011  234762_x_at  1.327976  8.877313e-16
# 51488    242239_at  1.355543  1.382813e-15
# 30080  220796_x_at  1.424474  1.400345e-15
# 52691  243442_x_at  1.200798  1.788807e-15
# 54028  244778_x_at  1.168161  3.288118e-15
# 35930  226675_s_at  1.350436  3.548547e-15
# 25814  216524_x_at  1.190433  4.962717e-15
# 31052  221772_s_at -1.419422  5.891257e-15
# 36061  226806_s_at  1.252825  7.098147e-15
# 44238    234989_at  2.197910  8.121272e-15
# 42565    233313_at  1.189468  8.278580e-15

# %% [markdown]
# ## Step 6: Differential Expression Analysis (t-test)
#
# We perform a t-test for each gene to check if expression is significantly different
# between Alzheimer’s and control samples.
#
# - **Log Fold Change (logFC)** shows how much expression changes between groups.
# - **p-value** shows the statistical significance of the difference.
#
# We then create a table of the top 20 most significant genes.

# %%
# 1️⃣ Get sample metadata (phenotype info)
meta_data = pd.DataFrame({gsm: gse.gsms[gsm].metadata for gsm in gse.gsms}).T

# Extract group info (Alzheimer's vs Control)
meta_data['group'] = meta_data['characteristics_ch1'].apply(lambda x: "Alzheimers" if "Alzheimer" in str(x) else "Control")

# 2️⃣ Align expression_df columns with metadata
expression_df = expression_df.loc[:, meta_data.index]

# 3️⃣ Split into groups
alz_samples = expression_df.loc[:, meta_data[meta_data['group'] == "Alzheimers"].index]
control_samples = expression_df.loc[:, meta_data[meta_data['group'] == "Control"].index]

# 4️⃣ Calculate log fold change
log_fc = np.log2(alz_samples.mean(axis=1) / control_samples.mean(axis=1))

# 5️⃣ Perform t-test for p-values
p_values = []
for gene in expression_df.index:
    t_stat, p_val = stats.ttest_ind(alz_samples.loc[gene], control_samples.loc[gene], equal_var=False)
    p_values.append(p_val)

results_df = pd.DataFrame({
    "Gene": expression_df.index,
    "logFC": log_fc,
    "p_value": p_values
})

# 6️⃣ Volcano Plot
plt.figure(figsize=(6,4))
plt.scatter(results_df["logFC"], -np.log10(results_df["p_value"]), alpha=0.7)
plt.xlabel("Log2 Fold Change")
plt.ylabel("-Log10 p-value")
plt.title("Volcano Plot")
plt.axhline(-np.log10(0.05), color='red', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ## Step 7: Differential Expression Analysis & Volcano Plot
#
# In this step, we compare gene expression levels between Alzheimer's and control samples.
#
# - We extract **sample groups** (Alzheimer's vs Control) from the metadata.
# - For each gene, we calculate:
#   - **Log Fold Change (logFC):** Measures how much expression changes between groups.
#   - **p-value:** Tests if the difference is statistically significant.
#
# Finally, we create a **Volcano Plot**:
# - X-axis = Log2 Fold Change
# - Y-axis = -Log10 p-value
# - Genes above the red line are statistically significant.

# %% [markdown]
# ## Step 8: Conclusion
#
# PCA showed a partial separation of Alzheimer's and control samples, indicating differences in their gene expression patterns.
# - Differential expression analysis identified several genes with significant changes between groups.
# - The volcano plot highlighted these genes, suggesting potential biomarkers for Alzheimer’s disease.
